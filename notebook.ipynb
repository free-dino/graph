# %%
folder_to_scan = "solvers"

import hashlib
import os

def get_file_hash(file_path):
    """Calculate SHA-256 hash of a single file."""
    sha256_hash = hashlib.sha256()
    try:
        with open(file_path, "rb") as f:
            # Read file in 64kb chunks to handle large files
            for byte_block in iter(lambda: f.read(65536), b""):
                sha256_hash.update(byte_block)
        return sha256_hash.hexdigest()
    except Exception as e:
        return f"Error: {e}"

def hash_folder_files(directory_path):
    """Iterate through a folder and print the hash of each file."""
    if not os.path.isdir(directory_path):
        print(f"Error: {directory_path} is not a valid directory.")
        return

    print(f"{'File Name':<30} | {'SHA-256 Hash'}")
    print("-" * 100)

    # Use os.listdir for files in the immediate folder
    # Use os.walk(directory_path) if you need to include subfolders
    for filename in os.listdir(directory_path):
        file_path = os.path.join(directory_path, filename)
        
        # Only process files, skip directories
        if os.path.isfile(file_path):
            file_hash = get_file_hash(file_path)
            print(f"{filename:<30} | {file_hash}")

# Replace with your actual folder path
hash_folder_files(folder_to_scan)
# Out:
# File Name                      | SHA-256 Hash
# ----------------------------------------------------------------------------------------------------
# aco_solver.py                  | 23ef2da7d4c08d56607e85daba0bce928a1c7318049456730ce99115544285b5
# greedy_bfs.py                  | d63141c7b02a22a64de20ee3a537a1f19e3de3ea76fa6568a04c1ee264240681
# vrp_ortools.py                 | 236f51c177d05082495412957866bcaaf94d1ec55773ff1212813be1f6fb5c06
# mapd_cbs_solver.py             | 48e1820f937e8629d1206f0f983eb4f2fca76a2d055332f9074b355baa8d24cd
# solver.py                      | 790809a56baf95bbd5873b325e8cacd46055e73c43f9ca049061a86a50f79145

# %%
# !python run_test.py --method ACOSolver --config test_config.txt --out results #--seed 42
# Out:
# Đang load solver modules ...
# Load thành công.
# Chạy phương pháp: ACOSolver
# Solver sẽ chạy: ACOSolver
#
# Đọc config: test_config.txt
# Tìm thấy 6 config.
#
# [C1] N=7 C=2 G=15 T=240  (còn 60.0 phút)
#   Chế độ online: chỉ G được biết trước; từng đơn được sinh/reveal trong step t.
#   [ACO] Net reward: 0.00
#     Giao/Tổng: 0/15  đúng hạn=0  trễ=0  bỏ lỡ=15  generated=15  t=0.93s
#
# [C2] N=10 C=2 G=25 T=240  (còn 60.0 phút)
#   Chế độ online: chỉ G được biết trước; từng đơn được sinh/reveal trong step t.
#   [ACO] Net reward: 0.00
#     Giao/Tổng: 0/25  đúng hạn=0  trễ=0  bỏ lỡ=25  generated=25  t=1.76s
#
# [C3] N=12 C=3 G=40 T=360  (còn 60.0 phút)
#   Chế độ online: chỉ G được biết trước; từng đơn được sinh/reveal trong step t.
#   [ACO] Net reward: 0.00
#     Giao/Tổng: 0/40  đúng hạn=0  trễ=0  bỏ lỡ=40  generated=40  t=5.12s
#
# [C4] N=15 C=4 G=60 T=600  (còn 59.9 phút)
#   Chế độ online: chỉ G được biết trước; từng đơn được sinh/reveal trong step t.
#   [ACO] Net reward: 0.00
#     Giao/Tổng: 0/60  đúng hạn=0  trễ=0  bỏ lỡ=60  generated=60  t=11.71s
#
# [C5] N=18 C=5 G=80 T=780  (còn 59.7 phút)
#   Chế độ online: chỉ G được biết trước; từng đơn được sinh/reveal trong step t.
#   [ACO] Net reward: 0.00
#     Giao/Tổng: 0/80  đúng hạn=0  trễ=0  bỏ lỡ=80  generated=80  t=21.04s
#
# [C6] N=20 C=5 G=100 T=960  (còn 59.3 phút)
#   Chế độ online: chỉ G được biết trước; từng đơn được sinh/reveal trong step t.
#   [ACO] Net reward: 0.00
#     Giao/Tổng: 0/100  đúng hạn=0  trễ=0  bỏ lỡ=100  generated=100  t=34.63s
#
# ====================================================================================================
# Config     Method                         Net Reward    %Giao  %Đúng hạn    t(s)
# ----------------------------------------------------------------------------------------------------
# C1         ACO                                  0.00     0.0%       0.0%     0.9
# C2         ACO                                  0.00     0.0%       0.0%     1.8
# C3         ACO                                  0.00     0.0%       0.0%     5.1
# C4         ACO                                  0.00     0.0%       0.0%    11.7
# C5         ACO                                  0.00     0.0%       0.0%    21.0
# C6         ACO                                  0.00     0.0%       0.0%    34.6
# ====================================================================================================
# TỔNG ĐIỂM THEO PHƯƠNG PHÁP:
# - ACO: 0.00
# Tổng thời gian chạy: 75.2s / 3600s
#
# Đã lưu tổng kết vào results/summary.json
# Đã lưu toàn bộ kết quả vào results/all_results.json
